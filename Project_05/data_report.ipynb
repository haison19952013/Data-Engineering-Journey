# %%
import os
import pandas as pd
import numpy as np

# %%
def export_ips_data_check(force_redo = False):
    if os.path.exists("data/ip_location_data_check.csv") and not force_redo:
        return pd.read_csv("data/ip_location_data_check.csv")
    else:
        input_dir = "data"
        input_prefix = "ips_batch_"
        output_prefix = "location_batch_"
        data_check_dict = {'inp_path':[], 'oup_path':[],'inp_rows': [], 'oup_rows': [], 'oup_success_rows': []}
        for inp_filename in sorted(os.listdir(input_dir)):
            if inp_filename.startswith(input_prefix) and inp_filename.endswith(".csv"):
                input_path = os.path.join(input_dir, inp_filename)
                batch_num = inp_filename.split("_")[2].split(".")[0]
                output_filename = f"{output_prefix}{batch_num}.csv"
                output_path = os.path.join(input_dir, output_filename)
                df_in = pd.read_csv(input_path)
                df_out = pd.read_csv(output_path)
                df_out.replace("-", np.nan, inplace = True)
                df_out.replace("INVALID IP ADDRESS", np.nan, inplace = True)
                data_check_dict['inp_path'].append(input_path)
                data_check_dict['oup_path'].append(output_path)
                data_check_dict['inp_rows'].append(len(df_in))
                data_check_dict['oup_rows'].append(len(df_out))
                df_out_nan = df_out[df_out.isnull().sum(axis = 1) >= 4]
                data_check_dict['oup_success_rows'].append(len(df_in) - len(df_out_nan))
        data_check_df = pd.DataFrame(data_check_dict)
        data_check_df.to_csv("data/ip_location_data_check.csv", index = False)
        return data_check_df

# %%
export_ips_df = export_ips_data_check(force_redo = True)
export_ips_df
# Out:
#                inp_path                   oup_path  inp_rows  oup_rows  \
# 0  data/ips_batch_1.csv  data/location_batch_1.csv    500000    500000
# 1  data/ips_batch_2.csv  data/location_batch_2.csv    500000    500000
# 2  data/ips_batch_3.csv  data/location_batch_3.csv    500000    500000
# 3  data/ips_batch_4.csv  data/location_batch_4.csv    500000    500000
# 4  data/ips_batch_5.csv  data/location_batch_5.csv    500000    500000
# 5  data/ips_batch_6.csv  data/location_batch_6.csv    500000    500000
# 6  data/ips_batch_7.csv  data/location_batch_7.csv    239628    239628
#
#    oup_success_rows
# 0            484398
# 1            489461
# 2            491616
# 3            499451
# 4            499748
# 5            499610
# 6            238576

# %%
print(export_ips_df.inp_rows.sum())
print(export_ips_df.oup_success_rows.sum())
# Out:
# 3239628
# 3202861

# %%
def export_prod_data_check(force_redo = False):
    if os.path.exists("data/prod_data_check.csv") and not force_redo:
        return pd.read_csv("data/prod_data_check.csv")
    else:
        input_dir = "data"
        input_prefix = "prod_batch_"
        output_prefix = "prod_url_batch_"
        data_check_dict = {'inp_path':[], 'oup_path':[],'inp_rows': [], 'oup_rows': [],
                           'inp_unique_prod_id_len': [], 'oup_unique_prod_id_len': [], 'diff_prod': []}
        for inp_filename in sorted(os.listdir(input_dir)):
            if inp_filename.startswith(input_prefix) and inp_filename.endswith(".csv"):
                input_path = os.path.join(input_dir, inp_filename)
                batch_num = inp_filename.split("_")[2].split(".")[0]
                output_filename = f"{output_prefix}{batch_num}.csv"
                output_path = os.path.join(input_dir, output_filename)
                df_in = pd.read_csv(input_path)
                df_out = pd.read_csv(output_path)
                df_out.replace("fail", np.nan, inplace = True)
                data_check_dict['inp_path'].append(input_path)
                data_check_dict['oup_path'].append(output_path)
                df_out_clean = df_out.dropna()
                data_check_dict['inp_rows'].append(len(df_in))
                data_check_dict['oup_rows'].append(len(df_out))
                unique_prod_in = set(df_in.product_id.unique().tolist())
                unique_prod_out = set(df_out_clean.product_id.unique().tolist())
                diff_prod = unique_prod_in.difference(unique_prod_out)
                data_check_dict['inp_unique_prod_id_len'].append(len(unique_prod_in))
                data_check_dict['oup_unique_prod_id_len'].append(len(unique_prod_out))
                data_check_dict['diff_prod'].append(list(diff_prod))
        data_check_df = pd.DataFrame(data_check_dict)
        data_check_df.to_csv("data/prod_data_check.csv", index = False)
        return data_check_df

export_prod_df = export_prod_data_check(force_redo = True)
export_prod_df
# Out:
#                   inp_path                    oup_path  inp_rows  oup_rows  \
# 0    data/prod_batch_1.csv   data/prod_url_batch_1.csv    500000      1699
# 1   data/prod_batch_10.csv  data/prod_url_batch_10.csv    500000       900
# 2   data/prod_batch_11.csv  data/prod_url_batch_11.csv    500000       842
# 3   data/prod_batch_12.csv  data/prod_url_batch_12.csv    500000       210
# 4   data/prod_batch_13.csv  data/prod_url_batch_13.csv    500000       295
# 5   data/prod_batch_14.csv  data/prod_url_batch_14.csv    500000       261
# 6   data/prod_batch_15.csv  data/prod_url_batch_15.csv    500000       172
# 7   data/prod_batch_16.csv  data/prod_url_batch_16.csv    500000       639
# 8   data/prod_batch_17.csv  data/prod_url_batch_17.csv    500000       271
# 9   data/prod_batch_18.csv  data/prod_url_batch_18.csv    500000       342
# 10  data/prod_batch_19.csv  data/prod_url_batch_19.csv    500000      1041
# 11   data/prod_batch_2.csv   data/prod_url_batch_2.csv    500000       598
# 12  data/prod_batch_20.csv  data/prod_url_batch_20.csv    500000      1061
# 13  data/prod_batch_21.csv  data/prod_url_batch_21.csv    500000       650
# 14  data/prod_batch_22.csv  data/prod_url_batch_22.csv    500000       723
# 15  data/prod_batch_23.csv  data/prod_url_batch_23.csv    500000       486
# 16  data/prod_batch_24.csv  data/prod_url_batch_24.csv    500000       912
# 17  data/prod_batch_25.csv  data/prod_url_batch_25.csv    354650       654
# 18   data/prod_batch_3.csv   data/prod_url_batch_3.csv    500000       705
# 19   data/prod_batch_4.csv   data/prod_url_batch_4.csv    500000        92
# 20   data/prod_batch_5.csv   data/prod_url_batch_5.csv    500000       559
# 21   data/prod_batch_6.csv   data/prod_url_batch_6.csv    500000       878
# 22   data/prod_batch_7.csv   data/prod_url_batch_7.csv    500000      3584
# 23   data/prod_batch_8.csv   data/prod_url_batch_8.csv    500000      1042
# 24   data/prod_batch_9.csv   data/prod_url_batch_9.csv    500000       491
#
#     inp_unique_prod_id_len  oup_unique_prod_id_len  \
# 0                     1699                    1669
# 1                      949                     711
# 2                     1066                     821
# 3                      212                     210
# 4                      295                     295
# 5                      265                     260
# 6                      172                     167
# 7                      676                     629
# 8                      272                     269
# 9                      342                     328
# 10                    1041                    1039
# 11                     603                     579
# 12                    1061                    1059
# 13                     650                     645
# 14                     723                     711
# 15                     486                     479
# 16                     912                     886
# 17                     654                     651
# 18                     707                     639
# 19                      92                      90
# 20                     559                     556
# 21                     878                     876
# 22                    3584                    3470
# 23                    1042                    1014
# 24                     500                     414
#
#                                             diff_prod
# 0   [101377, 100111, 101406, 101032, 101292, 10039...
# 1   [111104, 80384, 80385, 80388, 111112, 111114, ...
# 2   [88581, 88588, 86030, 89109, 88598, 86039, 891...
# 3                                      [89220, 89222]
# 4                                                  []
# 5                 [90730, 90574, 90575, 90576, 90686]
# 6                 [90874, 90875, 90876, 90877, 90879]
# 7   [91284, 91287, 91288, 91289, 91690, 91693, 913...
# 8                               [92074, 92067, 92151]
# 9   [92548, 92553, 92554, 92560, 92561, 92562, 925...
# 10                                     [92858, 95212]
# 11  [102535, 102536, 102537, 102538, 102539, 10254...
# 12                                     [96347, 96428]
# 13                [96640, 96620, 97105, 97106, 96694]
# 14  [97824, 97260, 97261, 97262, 97263, 97264, 972...
# 15  [98178, 98054, 98225, 98226, 98227, 98070, 98205]
# 16  [99072, 99073, 99204, 99205, 98446, 98963, 988...
# 17                              [99491, 99692, 99390]
# 18  [103040, 102834, 102541, 102542, 102543, 10254...
# 19                                   [103409, 103358]
# 20                           [103473, 103610, 103573]
# 21                                   [104132, 104157]
# 22  [107554, 105511, 105513, 105515, 105517, 10552...
# 23  [108931, 108932, 108933, 108934, 109711, 10908...
# 24  [110593, 110601, 110137, 110165, 110171, 11017...

# %%
print(export_prod_df.inp_unique_prod_id_len.sum())
print(export_prod_df.oup_unique_prod_id_len.sum())
# Out:
# 19440
# 18467
